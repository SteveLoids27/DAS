# %%
import pandas as pd

# %%
data=pd.read_csv("thanksgiving.csv",encoding="latin-1")

# %%
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
data.shape
# Out:
# (1058, 65)

# %%
data.tail()
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 1053                                             Turkey
# 1054                                             Turkey
# 1055                             Other (please specify)
# 1056                                             Turkey
# 1057                                             Turkey
#
#      What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 1053                                                NaN
# 1054                                                NaN
# 1055                                               Duck
# ...

# %%
data["Do you celebrate Thanksgiving?"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data["What type of cranberry saucedo you typically have?"].value_counts() #grouping data with pandas
# Out:
# Canned                    502
# Homemade                  301
# None                      146
# Other (please specify)     25
# Name: What type of cranberry saucedo you typically have?, dtype: int64

# %%
homemade_df=data[data["What type of cranberry saucedo you typically have?"]=="Homemade"] #Create a dataframe by filtering values"Housemade"

# %%
homemade_df
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 5       4337929779                            Yes
# 7       4337916002                            Yes
# 13      4337878450                            Yes
# ...            ...                            ...
# 1034    4335954394                            Yes
# 1048    4335949112                            Yes
# 1049    4335947496                            Yes
# 1053    4335944082                            Yes
# 1056    4335934708                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 2                                                Turkey
# 3                                                Turkey
# 5                                                Turkey
# 7                                                Turkey
# 13                                               Turkey
# ...

# %%
grouped = data.groupby("What type of cranberry saucedo you typically have?")
grouped

# %%
grouped.groups
# Out:
# {'Canned': [4, 6, 8, 11, 12, 15, 18, 19, 26, 27, 38, 43, 48, 53, 58, 59, 60, 68, 69, 71, 74, 76, 79, 80, 86, 87, 89, 90, 91, 97, 103, 106, 107, 109, 115, 116, 118, 119, 123, 127, 129, 130, 132, 135, 136, 137, 140, 141, 143, 144, 145, 150, 153, 155, 156, 157, 158, 159, 161, 162, 163, 166, 167, 168, 169, 173, 179, 180, 181, 182, 184, 186, 190, 192, 193, 195, 198, 199, 200, 204, 205, 207, 209, 210, 211, 212, 213, 215, 217, 218, 220, 222, 224, 226, 229, 230, 231, 239, 243, 245, ...], 'Homemade': [2, 3, 5, 7, 13, 14, 16, 20, 21, 23, 25, 28, 30, 32, 33, 37, 39, 42, 44, 46, 52, 54, 56, 57, 62, 64, 66, 70, 82, 83, 85, 88, 93, 94, 96, 98, 101, 102, 108, 110, 111, 112, 114, 120, 122, 128, 134, 138, 139, 152, 165, 171, 172, 174, 175, 176, 177, 178, 183, 188, 189, 194, 201, 202, 203, 208, 219, 223, 225, 232, 234, 235, 236, 238, 241, 242, 244, 246, 248, 254, 255, 256, 259, 261, 262, 263, 264, 268, 281, 285, 286, 287, 290, 291, 292, 295, 298, 300, 302, 303, ...], 'None': [0, 17, 24, 29, 34, 36, 40
# ...

# %%
grouped.size()
# Out:
# What type of cranberry saucedo you typically have?
# Canned                    502
# Homemade                  301
# None                      146
# Other (please specify)     25
# dtype: int64

# %%
data[:5]
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...
